# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_california_housing
califor_df  = fetch_california_housing()

# %%
x= pd.DataFrame(califor_df.data , columns=califor_df.feature_names)
y = califor_df.target

# %%
# x.head()

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
treeReg = DecisionTreeRegressor(max_depth=15)

# %%
treeReg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=15)

# %%
ypred = treeReg.predict(X_test)

from sklearn.metrics import r2_score
score = r2_score(ypred , y_test)
score
# Out:
# 0.6067136775286248

# %%
# from sklearn import tree
# plt.figure(figsize=(15,10))
# tree.plot_tree(treeReg, filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[0] <= 5.291\nsquared_error = 1.331\nsamples = 13828\nvalue = 2.067'),
#  Text(0.25, 0.75, 'x[0] <= 3.135\nsquared_error = 0.86\nsamples = 11372\nvalue = 1.766'),
#  Text(0.375, 0.8333333333333333, 'True  '),
#  Text(0.125, 0.5833333333333334, 'x[2] <= 4.209\nsquared_error = 0.567\nsamples = 5501\nvalue = 1.371'),
#  Text(0.0625, 0.4166666666666667, 'x[5] <= 2.441\nsquared_error = 0.708\nsamples = 2009\nvalue = 1.674'),
#  Text(0.03125, 0.25, 'x[6] <= 37.925\nsquared_error = 1.074\nsamples = 604\nvalue = 2.105'),
#  Text(0.015625, 0.08333333333333333, 'squared_error = 1.079\nsamples = 514\nvalue = 2.246'),
#  Text(0.046875, 0.08333333333333333, 'squared_error = 0.286\nsamples = 90\nvalue = 1.3'),
#  Text(0.09375, 0.25, 'x[0] <= 2.221\nsquared_error = 0.436\nsamples = 1405\nvalue = 1.489'),
#  Text(0.078125, 0.08333333333333333, 'squared_error = 0.451\nsamples = 793\nvalue = 1.333'),
# ...
